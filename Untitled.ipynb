# %%
import pandas as pd

# %%
pd
# Out:
# <module 'pandas' from 'D:\\anaconda3\\envs\\py36\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df = pd.read_csv('C:\\Users\\zhtang\\Desktop\\NV-DVFS-Benchmark\\csvs\\v1\\gtx980-high-dvfs-real-small-workload-Performance.csv',header=0)

# %%
df.head(5)
# Out:
#         appName  coreF  memF    argNo           kernel   time/ms  \
# 0  BlackScholes   1100  2100  input00  BlackScholesGPU  0.080747
# 1  BlackScholes   1100  2600  input00  BlackScholesGPU  0.064559
# 2  BlackScholes   1100  3100  input00  BlackScholesGPU  0.054343
# 3  BlackScholes   1100  3600  input00  BlackScholesGPU  0.048982
# 4  BlackScholes   1100  3900  input00  BlackScholesGPU  0.046982
#
#                  blocks    warps  achieved_occupancy  sm_efficiency    ...     \
# 0  (3584 1 1) (128 1 1)  14336.0            0.872695         0.9404    ...
# 1  (3584 1 1) (128 1 1)  14336.0            0.856753         0.9300    ...
# 2  (3584 1 1) (128 1 1)  14336.0            0.844897         0.9201    ...
# 3  (3584 1 1) (128 1 1)  14336.0            0.841159         0.9103    ...
# 4  (3584 1 1) (128 1 1)  14336.0            0.836894         0.9011    ...
#
#    flop_count_dp_fma  flop_count_sp  flop_count_sp_fma  flop_count_sp_special  \
# ...

# %%
df.tail(3)
# Out:
#        appName  coreF  memF    argNo     kernel  time/ms  \
# 747  vectorAdd    900  3100  input00  vectorAdd  1.13910
# 748  vectorAdd    900  3600  input00  vectorAdd  0.98313
# 749  vectorAdd    900  3900  input00  vectorAdd  0.98232
#
#                     blocks     warps  achieved_occupancy  sm_efficiency  \
# 747  (65536 1 1) (256 1 1)  524288.0            0.848713         0.9957
# 748  (65536 1 1) (256 1 1)  524288.0            0.839627         0.9950
# 749  (65536 1 1) (256 1 1)  524288.0            0.839315         0.9950
#
#        ...     flop_count_dp_fma  flop_count_sp  flop_count_sp_fma  \
# 747    ...                     0       16777216                  0
# 748    ...                     0       16777216                  0
# 749    ...                     0       16777216                  0
#
#      flop_count_sp_special  inst_integer  inst_fp_32  inst_fp_64  \
# 747                      0     201326592    16777216           0
# ...

# %%
df.columns
# Out:
# Index(['appName', 'coreF', 'memF', 'argNo', 'kernel', 'time/ms', 'blocks',
#        'warps', 'achieved_occupancy', 'sm_efficiency',
#        'warp_execution_efficiency', 'eligible_warps_per_cycle',
#        'branch_efficiency', 'cf_executed', 'gld_throughput',
#        'gld_transactions', 'gld_transactions_per_request', 'gst_throughput',
#        'gst_transactions', 'gst_transactions_per_request', 'global_hit_rate',
#        'dram_read_transactions', 'dram_read_throughput',
#        'dram_write_transactions', 'dram_write_throughput',
#        'l2_read_transactions', 'l2_read_throughput', 'l2_write_transactions',
#        'l2_write_throughput', 'shared_load_transactions',
#        'shared_load_throughput', 'shared_load_transactions_per_request',
#        'shared_store_transactions', 'shared_store_throughput',
#        'shared_store_transactions_per_request', 'l2_tex_read_throughput',
#        'l2_tex_read_transactions', 'l2_tex_write_throughput',
# ...

# %%
len(df
   )
# Out:
# 750

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda3\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-ad11118bc8f3> in <module>()
# ----> 1 df[0]
#
# ...

# %%
df.columns
# Out:
# Index(['appName', 'coreF', 'memF', 'argNo', 'kernel', 'time/ms', 'blocks',
#        'warps', 'achieved_occupancy', 'sm_efficiency',
#        'warp_execution_efficiency', 'eligible_warps_per_cycle',
#        'branch_efficiency', 'cf_executed', 'gld_throughput',
#        'gld_transactions', 'gld_transactions_per_request', 'gst_throughput',
#        'gst_transactions', 'gst_transactions_per_request', 'global_hit_rate',
#        'dram_read_transactions', 'dram_read_throughput',
#        'dram_write_transactions', 'dram_write_throughput',
#        'l2_read_transactions', 'l2_read_throughput', 'l2_write_transactions',
#        'l2_write_throughput', 'shared_load_transactions',
#        'shared_load_throughput', 'shared_load_transactions_per_request',
#        'shared_store_transactions', 'shared_store_throughput',
#        'shared_store_transactions_per_request', 'l2_tex_read_throughput',
#        'l2_tex_read_transactions', 'l2_tex_write_throughput',
# ...

# %%
df[df.appName=='BlackScholes']
# Out:
#          appName  coreF  memF    argNo           kernel   time/ms  \
# 0   BlackScholes   1100  2100  input00  BlackScholesGPU  0.080747
# 1   BlackScholes   1100  2600  input00  BlackScholesGPU  0.064559
# 2   BlackScholes   1100  3100  input00  BlackScholesGPU  0.054343
# 3   BlackScholes   1100  3600  input00  BlackScholesGPU  0.048982
# 4   BlackScholes   1100  3900  input00  BlackScholesGPU  0.046982
# 5   BlackScholes   1300  2100  input00  BlackScholesGPU  0.080661
# 6   BlackScholes   1300  2600  input00  BlackScholesGPU  0.064020
# 7   BlackScholes   1300  3100  input00  BlackScholesGPU  0.053509
# 8   BlackScholes   1300  3600  input00  BlackScholesGPU  0.046969
# 9   BlackScholes   1300  3900  input00  BlackScholesGPU  0.043750
# 10  BlackScholes   1500  2100  input00  BlackScholesGPU  0.080708
# 11  BlackScholes   1500  2600  input00  BlackScholesGPU  0.063987
# 12  BlackScholes   1500  3100  input00  BlackScholesGPU  0.053085
# ...

# %%
df.iloc[2]
# Out:
# appName                                          BlackScholes
# coreF                                                    1100
# memF                                                     3100
# argNo                                                 input00
# kernel                                        BlackScholesGPU
# time/ms                                              0.054343
# blocks                                   (3584 1 1) (128 1 1)
# warps                                                   14336
# achieved_occupancy                                   0.844897
# sm_efficiency                                          0.9201
# warp_execution_efficiency                                   1
# eligible_warps_per_cycle                              4.26181
# branch_efficiency                                           1
# cf_executed                                            243712
# gld_throughput                                         91.094
# ...

# %%
df.loc['BlackScholes']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# D:\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [BlackScholes] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-9860142a6a30> in <module>()
# ----> 1 df.loc['BlackScholes']
#
# ...

# %%
decade_rain.unstack(0
                   )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c4afe63f9332> in <module>()
# ----> 1 decade_rain.unstack(0
#       2                    )
#
# NameError: name 'decade_rain' is not defined

# %%
df['appName']
# Out:
# 0      BlackScholes
# 1      BlackScholes
# 2      BlackScholes
# 3      BlackScholes
# 4      BlackScholes
# 5      BlackScholes
# 6      BlackScholes
# 7      BlackScholes
# 8      BlackScholes
# 9      BlackScholes
# 10     BlackScholes
# 11     BlackScholes
# 12     BlackScholes
# 13     BlackScholes
# 14     BlackScholes
# 15     BlackScholes
# 16     BlackScholes
# 17     BlackScholes
# 18     BlackScholes
# 19     BlackScholes
# 20     BlackScholes
# 21     BlackScholes
# 22     BlackScholes
# 23     BlackScholes
# 24     BlackScholes
# 25        SobolQRNG
# 26        SobolQRNG
# 27        SobolQRNG
# 28        SobolQRNG
# 29        SobolQRNG
#            ...
# 720       transpose
# 721       transpose
# 722       transpose
# 723       transpose
# 724       transpose
# 725       vectorAdd
# 726       vectorAdd
# 727       vectorAdd
# 728       vectorAdd
# 729       vectorAdd
# 730       vectorAdd
# 731       vectorAdd
# 732       vectorAdd
# 733       vectorAdd
# ...

# %%
df
# Out:
#           appName  coreF  memF    argNo              kernel   time/ms  \
# 0    BlackScholes   1100  2100  input00     BlackScholesGPU  0.080747
# 1    BlackScholes   1100  2600  input00     BlackScholesGPU  0.064559
# 2    BlackScholes   1100  3100  input00     BlackScholesGPU  0.054343
# 3    BlackScholes   1100  3600  input00     BlackScholesGPU  0.048982
# 4    BlackScholes   1100  3900  input00     BlackScholesGPU  0.046982
# 5    BlackScholes   1300  2100  input00     BlackScholesGPU  0.080661
# 6    BlackScholes   1300  2600  input00     BlackScholesGPU  0.064020
# 7    BlackScholes   1300  3100  input00     BlackScholesGPU  0.053509
# 8    BlackScholes   1300  3600  input00     BlackScholesGPU  0.046969
# 9    BlackScholes   1300  3900  input00     BlackScholesGPU  0.043750
# 10   BlackScholes   1500  2100  input00     BlackScholesGPU  0.080708
# 11   BlackScholes   1500  2600  input00     BlackScholesGPU  0.063987
# ...

# %%
df[(df.appName == 'BlackScholes')]['achieved_occupancy']
# Out:
# 0     0.872695
# 1     0.856753
# 2     0.844897
# 3     0.841159
# 4     0.836894
# 5     0.876647
# 6     0.864242
# 7     0.852980
# 8     0.845540
# 9     0.839912
# 10    0.881143
# 11    0.872351
# 12    0.860791
# 13    0.849847
# 14    0.845588
# 15    0.851970
# 16    0.843532
# 17    0.845181
# 18    0.845182
# 19    0.846817
# 20    0.863547
# 21    0.850866
# 22    0.842682
# 23    0.839760
# 24    0.840013
# Name: achieved_occupancy, dtype: float64

# %%
a = df[(df.coreF == 1100) & (df.memF == 2100)]['achieved_occupancy']

# %%
for t in a:
    b = t + 1

# %%
sd

# %%
a
# Out:
# 0      0.872695
# 25     0.961205
# 50     0.973945
# 75     0.956125
# 100    0.227133
# 125    0.359426
# 150    0.913205
# 175    0.900703
# 200    0.830800
# 225    0.307093
# 250    0.249990
# 275    0.830447
# 300    0.232274
# 325    0.893107
# 350    0.724615
# 375    0.973741
# 400    0.979680
# 425    0.976979
# 450    0.886005
# 475    0.977729
# 500    0.717162
# 525    0.918106
# 550    0.996529
# 575    0.950554
# 600    0.893043
# 625    0.989022
# 650    0.971800
# 675    0.970595
# 700    0.910510
# 725    0.872945
# Name: achieved_occupancy, dtype: float64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
b
# Out:
# 1.872945
